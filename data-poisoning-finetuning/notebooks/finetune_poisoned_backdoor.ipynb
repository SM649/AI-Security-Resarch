# %% [markdown]
# # Data Poisoning Backdoor Fine-Tune
#
# Fine-tunes Qwen2.5-1.5B-Instruct with LoRA on a clean+poisoned mixed dataset, and separately on a clean-only control set. Run on a Colab GPU runtime.
#
# Steps:
# 1. Install deps
# 2. Upload `clean_examples.jsonl` and `poisoned_examples.jsonl`
# 3. Build mixed training set (shuffle once, save the mix used)
# 4. LoRA fine-tune: poisoned run
# 5. LoRA fine-tune: clean-only control run
# 6. Download both adapters

# %%
# !pip install -q transformers peft accelerate bitsandbytes

# %%
# TODO: upload clean_examples.jsonl and poisoned_examples.jsonl, then load + shuffle + mix them here.

# %%
# TODO: LoRA fine-tune poisoned run (base model: Qwen/Qwen2.5-1.5B-Instruct).

# %%
# TODO: LoRA fine-tune clean-only control run (same clean_examples.jsonl, no poison).

# %%
# TODO: zip and download both adapters for local eval.
